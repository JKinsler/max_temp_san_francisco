# %% [markdown]
# # Temperature measurements from San Francisco
# This repository loads data from NOAA city temperature dataset and plots it. The specific data used here is for San Francisco's maximum december temperature, years 1945 to 2023.
#
# Please refer to NOAA's [Climate At A Glance City Time Series](https://www.ncei.noaa.gov/access/monitoring/climate-at-a-glance/city/time-series/USW00023234/tmax/12/12/1945-2023) to explore the dataset.

# %%
# !pip install hvplot

import hvplot.pandas
import pandas as pd
# Out:
# Requirement already satisfied: hvplot in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (0.8.4)
# Requirement already satisfied: packaging in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from hvplot) (23.1)
# Requirement already satisfied: holoviews>=1.11.0 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from hvplot) (1.17.1)
# Requirement already satisfied: panel>=0.11.0 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from hvplot) (1.2.2)
# Requirement already satisfied: numpy>=1.15 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from hvplot) (1.25.2)
# Requirement already satisfied: colorcet>=2 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: pandas in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from hvplot) (2.1.0)
# Requirement already satisfied: param>=1.9.0 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from hvplot) (1.13.0)
# Requirement already satisfied: bokeh>=1.0.0 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from hvplot) (3.2.2)
# Requirement already satisfied: contourpy>=1 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (1.1.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (2023.7.0)
# Requirement already satisfied: pillow>=7.1.0 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: tornado>=5.1 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (6.3.2)
# Requirement already satisfied: Jinja2>=2.9 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from bokeh>=1.0.0->hvplot) (3.1.2)
# Requirement already satisfied: pyct>=0.4.4 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from colorcet>=2->hvplot) (0.5.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from holoviews>=1.11.0->hvplot) (3.0.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from pandas->hvplot) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from pandas->hvplot) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from panel>=0.11.0->hvplot) (4.65.0)
# Requirement already satisfied: requests in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from panel>=0.11.0->hvplot) (2.31.0)
# Requirement already satisfied: mdit-py-plugins in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from panel>=0.11.0->hvplot) (0.4.0)
# Requirement already satisfied: linkify-it-py in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from panel>=0.11.0->hvplot) (2.0.2)
# Requirement already satisfied: markdown-it-py in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from panel>=0.11.0->hvplot) (3.0.0)
# Requirement already satisfied: typing-extensions in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from panel>=0.11.0->hvplot) (4.7.1)
# Requirement already satisfied: markdown in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from panel>=0.11.0->hvplot) (3.4.4)
# Requirement already satisfied: bleach in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from panel>=0.11.0->hvplot) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.1)
# Requirement already satisfied: six>=1.5 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->hvplot) (1.16.0)
# Requirement already satisfied: webencodings in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from requests->panel>=0.11.0->hvplot) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from requests->panel>=0.11.0->hvplot) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from requests->panel>=0.11.0->hvplot) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/johannakinsler/anaconda3/lib/python3.10/site-packages (from requests->panel>=0.11.0->hvplot) (1.26.16)

# %%
# Get data from the NOAA city time-series dataset

sf_data_url = ("https://www.ncei.noaa.gov/access/monitoring/climate-at-a-glance/"
               "city/time-series/USW00023234/tmax/12/12/1945-2023.csv")

sf_temp_df = pd.read_csv(sf_data_url, header=3, names=['year', 'temp_f'])

# %%
# Convert temperature from Farenheit to Celcius

def convert(temperature):
    """Convert temperature to Celcius"""
    return temperature - 32 * 5 / 9


sf_temp_df['temp_c'] = sf_temp_df['temp_f'].apply(convert).round(decimals=1)
sf_temp_df
# Out:
#       year  temp_f  temp_c
# 0   194612    63.5    45.7
# 1   194712   -99.0  -116.8
# 2   194812    63.0    45.2
# 3   194912    62.8    45.0
# 4   195012    64.1    46.3
# ..     ...     ...     ...
# 72  201812   -99.0  -116.8
# 73  201912    66.6    48.8
# 74  202012    67.9    50.1
# 75  202112    66.7    48.9
# 76  202212    67.0    49.2
#
# [77 rows x 3 columns]

# %%
# Convert the year column to a clean year format
sf_temp_df.year = pd.to_datetime(
    sf_temp_df.year, format='%Y%m', yearfirst=True
).dt.year
sf_temp_df
# Out:
#     year  temp_f  temp_c
# 0   1946    63.5    45.7
# 1   1947   -99.0  -116.8
# 2   1948    63.0    45.2
# 3   1949    62.8    45.0
# 4   1950    64.1    46.3
# ..   ...     ...     ...
# 72  2018   -99.0  -116.8
# 73  2019    66.6    48.8
# 74  2020    67.9    50.1
# 75  2021    66.7    48.9
# 76  2022    67.0    49.2
#
# [77 rows x 3 columns]

# %%
sf_temp_df.hvplot(
    x='year', 
    y='temp_c', 
    title='LA max temp'
)
# Out:
# /Users/johannakinsler/anaconda3/lib/python3.10/site-packages/holoviews/core/data/pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# /Users/johannakinsler/anaconda3/lib/python3.10/site-packages/holoviews/core/data/pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# :Curve   [year]   (temp_c)
